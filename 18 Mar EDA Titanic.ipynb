# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#pd.DataFrame()  #from a numpy array or dictionary
#pd.read_csv()   #from a csv file
#pd.read_excel()  #from an excel file
#pd.read_html()
#pd.read_table()  #from a tsv or tabular data

# %%
df=pd.read_csv("/content/drive/MyDrive/RNSIT March17/train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df[2:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#              Ticket    Fare Cabin Embarked
# 2  STON/O2. 3101282   7.925   NaN        S
# 3            113803  53.100  C123        S
# 4            373450   8.050   NaN        S

# %%
df[11:15] #splicing along the rows
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 11           12         1       1              Bonnell, Miss. Elizabeth
# 12           13         0       3        Saundercock, Mr. William Henry
# 13           14         0       3           Andersson, Mr. Anders Johan
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
#
#        Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 11  female  58.0      0      0     113783  26.5500  C103        S
# 12    male  20.0      0      0  A/5. 2151   8.0500   NaN        S
# 13    male  39.0      1      5     347082  31.2750   NaN        S
# 14  female  14.0      0      0     350406   7.8542   NaN        S

# %%
df[['PassengerId']]
# Out:
#      PassengerId
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ..           ...
# 886          887
# 887          888
# 888          889
# 889          890
# 890          891
#
# [891 rows x 1 columns]

# %%
df.iloc[10:15,6:9]  #splicing along both rows and columns
# Out:
#     SibSp  Parch     Ticket
# 10      1      1    PP 9549
# 11      0      0     113783
# 12      0      0  A/5. 2151
# 13      1      5     347082
# 14      0      0     350406

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
z1=df.isnull().sum()
z1
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
type(z1)
# Out:
# pandas.core.series.Series

# %%
z1.to_frame()
# Out:
#                0
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age          177
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin        687
# Embarked       2

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.nunique()   #no. of unqiue values in each column
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
x1=df['Survived'].value_counts()
x1
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
x1.index
# Out:
# Int64Index([0, 1], dtype='int64')

# %%
sns.countplot('Survived',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(y='Survived',data=df)
plt.show()

# %%
labels=['non-survived','survived']
plt.bar(labels,x1,color=['r','g'])
plt.show()

# %%
sns.countplot(x="Sex",data=df)
plt.show()

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df['Sex'].value_counts().index
# Out:
# Index(['male', 'female'], dtype='object')

# %%
plt.bar(df['Sex'].value_counts().index,df['Sex'].value_counts(),color=['r','g'])
plt.show()

# %%
sns.catplot(x="Sex",kind="count",data=df)
plt.show()

# %%
sns.catplot(x="Sex",kind="count",hue="Survived",data=df)
plt.show()

# %%
sns.catplot(x="Sex",kind="violin",y="Survived",data=df)
plt.show()

# %%
sns.catplot(x="Sex",kind="count",hue="Embarked",data=df)
plt.show()

# %%
sns.catplot(x="Sex",kind="violin",y="Survived",hue="Embarked",data=df)
plt.show()

# %%
sns.catplot(hue="Sex",kind="violin",y="Survived",x="Embarked",data=df)
plt.show()

# %%
sns.catplot(hue="Sex",kind="box",y="Survived",x="Embarked",data=df)
plt.show()

# %%
df['Pclass'].nunique()
# Out:
# 3

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
s=df['Pclass'].value_counts()
s
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
sns.countplot('Pclass',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.catplot(x='Pclass',data=df,kind="count")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'].isnull().sum()  #used to find the missing values in Age column
# Out:
# 177

# %%
891-177  #to find total number of non null values
# Out:
# 714

# %%
#Age Group assumptions
#Young: 0 to 20
#Young Adult: 21 to 40
#Mid Age: 41 to 60
#Old Age: Above 60

# %%
#age of the oldest person
np.max(df['Age'])
# Out:
# 80.0

# %%
np.min(df['Age'])  #youngest person
# Out:
# 0.42

# %%
#for reference to understand concept of sum and count
np.random.seed(1)
a=np.random.randint(0,100,10)
a
# Out:
# array([37, 12, 72,  9, 75,  5, 79, 64, 16,  1])

# %%
np.sum(a)
# Out:
# 370

# %%
np.sum(a>50)  #finding count of elemets greater than 50
# Out:
# 4

# %%
np.count_nonzero(a>50)
# Out:
# 4

# %%
np.count_nonzero((df['Age']>0) & (df['Age']<20))
np.count_nonzero(df['Age']<20)
np.sum((df['Age']>0) & (df['Age']<20))
# Out:
# 164

# %%
b_y=np.count_nonzero((df['Age']>0) & (df['Age']<=20))
b_a=np.count_nonzero((df['Age']>20) & (df['Age']<=40))
b_m=np.count_nonzero((df['Age']>40) & (df['Age']<=60))
b_o=np.count_nonzero(df['Age']>60)
print(b_y,b_a,b_m,b_o)
# Out:
# 179 385 128 22

# %%
labels=['Young','Adult','MiddleAge','OldAge']
plt.bar(labels,(b_y,b_a,b_m,b_o),color=['r','g','b','m'])
plt.show()

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df['Age'],bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <a list of 5 Patch objects>)

# %%
plt.hist(df['Age'],bins=[10,20,30,40,50,60,70,80])
# Out:
# (array([102., 220., 167.,  89.,  48.,  19.,   7.]),
#  array([10, 20, 30, 40, 50, 60, 70, 80]),
#  <a list of 7 Patch objects>)

# %%
plt.hist(df['Age'],bins=[10,20,30,40,50,60,70,80],
         edgecolor='k',color='green')
plt.xlabel("Ages")
plt.ylabel("Count of people in each age group")
plt.show()

# %%
sns.distplot(df['Age']) #distribution plot using normal distribution
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.pie((b_y,b_a,b_m,b_o),labels=labels,explode=[0,0,0.4,0],
        startangle=45,autopct="%0.1f")
plt.show()

# %%
#Groupby

# %%
class_group=df.groupby('Pclass').mean()
class_group
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
class_group['Survived']
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
class_group['Survived'].plot(kind='bar')
plt.show()

# %%
class_group['Fare'].plot(kind='bar')
plt.show()

# %%
class_group=df.groupby('Embarked').mean()
class_group
# Out:
#           PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Embarked
# C          445.357143  0.553571  1.886905  30.814769  0.386905  0.363095
# Q          417.896104  0.389610  2.909091  28.089286  0.428571  0.168831
# S          449.527950  0.336957  2.350932  29.445397  0.571429  0.413043
#
#                Fare
# Embarked
# C         59.954144
# Q         13.276030
# S         27.079812

# %%
class_group['Pclass'].plot(kind='bar')
